# %% [markdown]
# # Árvores de decisão: Scikit-learn
#
# ## O que vamos fazer?
# - Formar um modelo de regressão linear por árvores de decisão
# - Detetar se ocorrem desvios ou sobreajustes no modelo
# - Otimizar hiper-parâmetros com validação cruzada
# - Avaliar no subconjunto de teste
#
# Vamos resolver um problema de regressão linear multivariável semelhante aos exercícios anteriores, mas desta vez utilizando uma árvore de decisão para a regressão linear.
#
# Um exemplo que pode utilizar como referência para este exercício: [Decision Tree Regression](https://scikit-learn.org/stable/auto_examples/tree/plot_tree_regression.html)

# %%
# TODO: Importar todos os módulos necessários para esta célula

# %%
import numpy as np
from sklearn.datasets import make_regression
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle

# %% [markdown]
# ## Gerar um dataset sintético
#
# Gerar um conjunto de dados sintéticos com um valor de erro algo grande e poucas características:

# %%
# TODO: Gerar um dataset sintéticos para regressão linear com um termo de erro notável.

m = 1000
n = 3

X, Y, theta = make_regression(n_samples=m,  # Número de amostras
                              n_features=n,  # Número de variáveis independentes (features)
                              noise=10,       # Sem ruído
                              coef=True,     # Retorna os coeficientes verdadeiros
                              random_state=42)  # Para resultados reprodutíveis

# %%
# TODO: Representar graficamente o dataset para assegurar que o termo de erro é suficientemente alto

plt.figure(figsize=(15, 4))  # Ajusta o tamanho da figura (opcional)

# Gráfico 1
plt.subplot(1, 3, 1)  # 1 linha, 3 colunas, posição 1
plt.scatter(X[:, 0], Y, color='blue')
plt.title("Coluna 0")

# Gráfico 2
plt.subplot(1, 3, 2)
plt.scatter(X[:, 1], Y, color='red')
plt.title("Coluna 1")

# Gráfico 3
plt.subplot(1, 3, 3)
plt.scatter(X[:, 2], Y, color='green')
plt.title("Coluna 2")

plt.tight_layout()  
plt.show()

# %% [markdown]
# ## Pré-processar os dados
#
# - Reordenar os dados aleatoriamente.
# - Normalizar.
# - Dividi-los em subconjuntos de treino e testes.
#
# *Nota*: Mais uma vez, vamos utilizar a K-fold para a validação cruzada.

# %%
# TODO: Reordenar os dados aleatoriamente

X, Y = shuffle(X, Y, random_state=42)

# %%
# TODO: Normalizar os exemplos
scaler = MinMaxScaler().fit(X)
X_Scaled = scaler.transform(X)
print("X Normalizado:", X_Scaled[:3])
# Out:
# X Normalizado: [[0.26274563 0.35489232 0.44935472]
#  [0.50903947 0.24996968 0.3273369 ]
#  [0.73542396 0.39713036 0.46101096]]

# %%
# TODO: Dividir os dataset e subset de formação e testes

X_train, X_test, y_train, y_test = train_test_split(X_Scaled, Y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((800, 3), (200, 3))

# %% [markdown]
# ## Formar um modelo inicial
#
# Vamos começar a explorar modelos de árvores de decisão para a regressão com um modelo inicial.
#
# Para isso, formar um modelo de [sklearn.tree.DecissionTreeRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)  sobre o subset de formação:

# %%
# TODO: Formar uma árvore de regressão no subconjunto de formação com profundidade máxima 2

model_2 = DecisionTreeRegressor(max_depth=2, random_state=42)
model_2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %% [markdown]
# Verificar agora a adequação do modelo, avaliando-o no subset de teste:

# %%
# TODO: Avaliar o modelo com MSE e R^2 no subset de teste.

y_test_pred_2 = model_2.predict(X_test)

mse_2 = mean_squared_error(y_test, y_test_pred_2)
r2_2 = r2_score(y_test, y_test_pred_2)
print('Erro quadrático médio:', round(mse_2, 2)) 
print('Coeficiente de determinação:', round(r2_2, 2))
# Out:
# Erro quadrático médio: 7109.47
# Coeficiente de determinação: 0.53

# %% [markdown]
# *Acha que há desvio ou sobreajuste neste modelo?* Para o fazer, comparar a sua exatidão com a calculada no subset de treino:

# %%
y_train_pred = model_2.predict(X_train)

mse = mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)
print('Erro quadrático médio:', round(mse, 2)) 
print('Coeficiente de determinação:', round(r2, 2))
# Out:
# Erro quadrático médio: 6439.65
# Coeficiente de determinação: 0.61

# %% [markdown]
# Como dissemos, as árvores de decisão tendem a sobreajustar, a ajustar demasiado os dados usados na sua formação e, por vezes, não poder prever bem os novos exemplos.
#
# Vamos comprovar graficamente, formando outro modelo com uma profundidade máxima muito maior de 6:

# %%
# TODO: Formar outra árvore de regressão no subconjunto de formação com profundidade máxima 6
model_6 = DecisionTreeRegressor(max_depth=6, random_state=42)
model_6.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, random_state=42)

# %%
# TODO: Avaliar o modelo com MSE e R^2 no subconjunto de formação

y_test_pred_6 = model_6.predict(X_test)

mse_6 = mean_squared_error(y_test, y_test_pred_6)
r2_6 = r2_score(y_test, y_test_pred_6)
print('Erro quadrático médio:', round(mse_6, 2)) 
print('Coeficiente de determinação:', round(r2_6, 2))
# Out:
# Erro quadrático médio: 2107.56
# Coeficiente de determinação: 0.86

# %%
y_train_pred_6 = model_6.predict(X_train)

mse_6 = mean_squared_error(y_train, y_train_pred_6)
r2_6 = r2_score(y_train, y_train_pred_6)
print('Erro quadrático médio:', round(mse_6, 2)) 
print('Coeficiente de determinação:', round(r2_6, 2))
# Out:
# Erro quadrático médio: 744.24
# Coeficiente de determinação: 0.96

# %% [markdown]
# Comparar a precisão de formação deste modelo com o anterior (no subset de formação).
#
# *É maior ou menor ao aumentar a profundidade máxima da árvore?*

# %%
print("Max_depth: 2")
print('Erro quadrático médio:', round(mse_2, 2)) 
print('Coeficiente de determinação:', round(r2_2, 2))

print()

print("Max_depth: 6")
print('Erro quadrático médio:', round(mse_6, 2)) 
print('Coeficiente de determinação:', round(r2_6, 2))

print()

print("Como é visivel é melhor aumentar a profundidade da árvore. Mas até que ponto?")
# Out:
# Max_depth: 2
# Erro quadrático médio: 7109.47
# Coeficiente de determinação: 0.53
#
# Max_depth: 6
# Erro quadrático médio: 744.24
# Coeficiente de determinação: 0.96
#
# Como é visivel é melhor aumentar a profundidade da árvore. Mas até que ponto?

# %% [markdown]
# Agora vamos representar graficamente ambos os modelos, para comprovar se sofrem de desvio ou de sobreajuste.
#
# Para o fazer, pode guiar-se pelo exemplo anterior: [Decision Tree Regression](https://scikit-learn.org/stable/auto_examples/tree/plot_tree_regression.html)

# %%
plt.figure()
plt.scatter(X_Scaled[:, 0], Y, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot(X_test[:, 0], y_test_pred_2, color="cornflowerblue", label="max_depth=2", linewidth=2)
plt.plot(X_test[:, 0], y_test_pred_6, color="yellowgreen", label="max_depth=6", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
# TODO: Representar graficamente as previsões de ambos os modelos
residuos2 = y_test_pred_2 - y_test
residuos6 = y_test_pred_6 - y_test

plt.figure(2)

plt.title("Residuos com profundidade de 2 e 6")

plt.scatter(range(len(residuos2)), residuos2, color='blue', label='max_depth=2')
plt.scatter(range(len(residuos6)), residuos6, color='red', label='max_depth=6')

plt.grid(True)
plt.legend()

plt.show()

# %%
plt.figure(3)

plt.title("Previsão max_depth de 2 e 6")

plt.scatter(X_test[:, 0], y_test_pred_2, color='blue', label='max_depth=2')
plt.scatter(X_test[:, 0], y_test_pred_6, color='red', label='max_depth=6')

plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# Como vimos, geralmente uma profundidade máxima demasiado pequena leva a um modelo com desvio, um modelo que não é capaz de se ajustar bem à curva, enquanto uma profundidade máxima demasiado alta leva a um modelo com sobreajuste, um modelo que se ajusta bem demais à curva, mas que não tem uma boa precisão em exemplos futuros.
#
# Assim, em termos de árvores de regressão, temos um hiper-parâmetro, a profundidade máxima, que devemos otimizar através de validação cruzada. Também há outros hiper-parâmetros, tais como o critério para medir a qualidade de uma divisão, a estratégia para criar essa divisão, o número
# mínimo de exemplos necessários para dividir um nó, etc., etc.
#
# Para simplificar, vamos começar a realizar a validação cruzada apenas para encontrar o valor ótimo da profundidade máxima:

# %%
# TODO: Formar um modelo diferente para cada valor de *max_depth* considerado sobre um fold diferente.

# Valores de max_depth a considerar 
max_depths = list(range(1, 10))
print('Profundidades máx. a considerar:')
print(max_depths)

models = []
for i, depth in enumerate(max_depths):
    model = DecisionTreeRegressor(max_depth=i+1, random_state=42)
    model.fit(X_train, y_train)
    models.append(model)
# Out:
# Profundidades máx. a considerar:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## Avaliar o modelo sobre o subset de teste
#
# Finalmente, vamos avaliar o modelo sobre o subset de teste.
#
# Para o fazer, calcular as suas métricas de MSE e R^2 score e representar graficamente as previsões do modelo vs. o subset de teste:

# %%
# TODO: Avaliar o modelo com MSE e R^2 no subconjunto de teste.

for i, model in enumerate(models):
    print("Max_depth:", i+1)
    print(model)
    y_train_pred = model.predict(X_train)
    mse = mean_squared_error(y_train, y_train_pred)
    r2 = r2_score(y_train, y_train_pred)
    print("Subconjunto de Treino:")
    print('Erro quadrático médio:', round(mse, 2)) 
    print('Coeficiente de determinação:', round(r2, 2))
    print()
    y_test_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_test_pred)
    r2 = r2_score(y_test, y_test_pred)
    print("Subconjunto de Teste:")
    print('Erro quadrático médio:', round(mse, 2)) 
    print('Coeficiente de determinação:', round(r2, 2))
    
    print()
    print()
# Out:
# Max_depth: 1
# DecisionTreeRegressor(max_depth=1, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 10483.53
# Coeficiente de determinação: 0.37
#
# Subconjunto de Teste:
# Erro quadrático médio: 10438.71
# Coeficiente de determinação: 0.32
#
#
# Max_depth: 2
# DecisionTreeRegressor(max_depth=2, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 6439.65
# Coeficiente de determinação: 0.61
#
# Subconjunto de Teste:
# Erro quadrático médio: 7109.47
# Coeficiente de determinação: 0.53
#
#
# Max_depth: 3
# DecisionTreeRegressor(max_depth=3, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 3967.35
# Coeficiente de determinação: 0.76
#
# Subconjunto de Teste:
# Erro quadrático médio: 4278.97
# Coeficiente de determinação: 0.72
#
#
# Max_depth: 4
# DecisionTreeRegressor(max_depth=4, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 2429.77
# Coeficiente de determinação: 0.85
#
# Subconjunto de Teste:
# Erro quadrático médio: 3726.76
# Coeficiente de determinação: 0.76
#
#
# Max_depth: 5
# DecisionTreeRegressor(max_depth=5, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 1319.09
# Coeficiente de determinação: 0.92
#
# Subconjunto de Teste:
# Erro quadrático médio: 2639.34
# Coeficiente de determinação: 0.83
#
#
# Max_depth: 6
# DecisionTreeRegressor(max_depth=6, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 744.24
# Coeficiente de determinação: 0.96
#
# Subconjunto de Teste:
# Erro quadrático médio: 2107.56
# Coeficiente de determinação: 0.86
#
#
# Max_depth: 7
# DecisionTreeRegressor(max_depth=7, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 414.94
# Coeficiente de determinação: 0.98
#
# Subconjunto de Teste:
# Erro quadrático médio: 1720.26
# Coeficiente de determinação: 0.89
#
#
# Max_depth: 8
# DecisionTreeRegressor(max_depth=8, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 214.96
# Coeficiente de determinação: 0.99
#
# Subconjunto de Teste:
# Erro quadrático médio: 1347.11
# Coeficiente de determinação: 0.91
#
#
# Max_depth: 9
# DecisionTreeRegressor(max_depth=9, random_state=42)
# Subconjunto de Treino:
# Erro quadrático médio: 101.25
# Coeficiente de determinação: 0.99
#
# Subconjunto de Teste:
# Erro quadrático médio: 1257.36
# Coeficiente de determinação: 0.92

# %%
# TODO: Representar graficamente as previsões da melhor árvore do subset de teste

model_9 = DecisionTreeRegressor(max_depth=9, random_state=42)
model_9.fit(X_train, y_train)
y_test_pred_9 = model_9.predict(X_test)

plt.figure(3)

plt.title("Max_depth: 9 -> Y_test vs Y_test_predict")
plt.xlabel("Coluna 0 de X_test")
plt.ylabel("Y_test e Y_test_presdict")

# Representar num gráfico de pontos, o subset de teste
plt.scatter(X_test[:, 0], y_test, label="y_test")
plt.scatter(X_test[:, 0], y_test_pred_9, label="y_test_predict")
plt.legend()
plt.show()

# %%
# Representar num gráfico de linhas as previsões do modelo
# Como eixo horizontal, usa um espaço linear de um grande número de elementos entre o valor máximo y min. de X_test
x_axis = range(len(y_test_pred_9))

plt.plot(x_axis, y_test_pred_9)

plt.show()
